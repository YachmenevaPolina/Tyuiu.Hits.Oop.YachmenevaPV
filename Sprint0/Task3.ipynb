// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// #Вариант задания №8

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс CreditCard в C#, который будет представлять информацию
// о кредитных картах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

class CreditCard
{
    // Основные атрибуты
    public string CardNumber { get; set; }
    public string HolderName { get; set; }
    public string ExpiryDate { get; set; }
    public decimal Balance { get; set; }

    // Метод получения информации о карте
    public virtual string GetInfo()
    {
        return $"Номер карты: {CardNumber}\n" +
               $"Холдер: {HolderName}\n" +
               $"Срок действия: {ExpiryDate}\n" +
               $"Баланс: {Balance} руб.";
    }

    // Метод оплаты
    public virtual void Pay(decimal amount)
    {
        if (amount <= Balance)
        {
            Balance -= amount;
            Console.WriteLine($"Оплата на сумму {amount} руб. выполнена.");
        }
        else
        {
            Console.WriteLine("Недостаточно средств для оплаты.");
        }
    }

    // Метод проверки баланса
    public virtual void CheckBalance()
    {
        Console.WriteLine($"Баланс карты: {Balance} руб.");
    }
}

class GoldCreditCard : CreditCard
{
    // Дополнительный атрибут
    public int BonusMiles { get; set; }

    // Переопределение метода оплаты
    public override void Pay(decimal amount)
    {
        if (amount <= Balance)
        {
            Balance -= amount;

            int miles = (int)(amount / 100);
            BonusMiles += miles;

            Console.WriteLine($"Оплата на сумму {amount} руб. выполнена.");
            Console.WriteLine($"Начислено бонусных миль: {miles}.");
            Console.WriteLine($"Всего бонусных миль: {BonusMiles}.");
        }
        else
        {
            Console.WriteLine("Недостаточно средств для оплаты.");
        }
    }
}

class PremiumCreditCard : CreditCard
{
    // Дополнительный атрибут
    public string SupportAssistant { get; set; }

    // Переопределение метода проверки баланса
    public override void CheckBalance()
    {
        if (Balance >= 0)
        {
            Console.WriteLine($"Баланс карты: {Balance} руб.");
        }
        else
        {
            Console.WriteLine("Обнаружена проблема с балансом.");
            Console.WriteLine($"Обратитесь к ассистенту поддержки: {SupportAssistant}.");
        }
    }
}

class CorporateCreditCard : CreditCard
{
    // Дополнительный атрибут
    public string Company { get; set; }

    // Переопределение метода получения информации
    public override string GetInfo()
    {
        return $"Номер карты: {CardNumber}\n" +
               $"Холдер: {HolderName}\n" +
               $"Срок действия: {ExpiryDate}\n" +
               $"Баланс: {Balance} руб.\n" +
               $"Компания: {Company}";
    }
}

CreditCard card = new CreditCard();
card.CardNumber = "1111-2222-3333-4444";
card.HolderName = "Иван Иванов";
card.ExpiryDate = "28.12.2036";
card.Balance = 50000;

GoldCreditCard goldCard = new GoldCreditCard();
goldCard.CardNumber = "2222-3333-4444-5555";
goldCard.HolderName = "Петр Петров";
goldCard.ExpiryDate = "29.06.2030";
goldCard.Balance = 100000;
goldCard.BonusMiles = 500;

PremiumCreditCard premiumCard = new PremiumCreditCard();
premiumCard.CardNumber = "3333-4444-5555-6666";
premiumCard.HolderName = "Анна Смирнова";
premiumCard.ExpiryDate = "30.07.2029";
premiumCard.Balance = 75000;
premiumCard.SupportAssistant = "Анна";

CorporateCreditCard corporateCard = new CorporateCreditCard();
corporateCard.CardNumber = "4444-5555-6666-7777";
corporateCard.HolderName = "Сергей Сидоров";
corporateCard.ExpiryDate = "18.09.2028";
corporateCard.Balance = 200000;
corporateCard.Company = "ООО Ромашка";

Console.WriteLine("Обычная кредитная карта");
Console.WriteLine(card.GetInfo());
card.CheckBalance();

Console.WriteLine();

Console.WriteLine("Золотая кредитная карта");
Console.WriteLine(goldCard.GetInfo());
goldCard.Pay(10000);
goldCard.CheckBalance();

Console.WriteLine();

Console.WriteLine("Премиальная кредитная карта");
Console.WriteLine(premiumCard.GetInfo());
premiumCard.CheckBalance();

Console.WriteLine();

Console.WriteLine("Корпоративная кредитная карта");
Console.WriteLine(corporateCard.GetInfo());
corporateCard.Pay(15000);
corporateCard.CheckBalance();

Console.WriteLine();


CreditCard selectedCard;

selectedCard = goldCard;
selectedCard.Pay(1000);

selectedCard = premiumCard;
selectedCard.CheckBalance();

selectedCard = corporateCard;
Console.WriteLine(selectedCard.GetInfo());
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-$CACHE_BUSTER$' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://127.0.0.1:2049/","http://::1:2049/","http://fe80::1%1:2049/","http://fe80::c18:4398:ae60:e148%11:2049/","http://2a01:540:65ca:ca00:1:e13c:293c:e4ef:2049/","http://2a01:540:65ca:ca00:d902:b58:b3bd:132f:2049/","http://2a01:540:6287:1200:1496:a996:ffd3:3e54:2049/","http://2a01:540:6287:1200:5926:f9f3:da02:2f62:2049/","http://192.168.0.130:2049/","http://fe80::20dd:63ff:fe8a:1745%13:2049/","http://fe80::53ef:24f0:f310:a513%15:2049/","http://fe80::a21e:348c:8057:9f0d%16:2049/","http://fe80::2f14:a65c:db42:456a%17:2049/","http://fe80::ce81:b1c:bd2c:69e%18:2049/","http://fe80::be8d:8423:2003:f2c1%19:2049/","http://fe80::d02f:9dbb:1c24:3509%20:2049/","http://198.18.0.1:2049/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '76506.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>
// Обычная кредитная карта
// Номер карты: 1111-2222-3333-4444
// Холдер: Иван Иванов
// Срок действия: 28.12.2036
// Баланс: 50000 руб.
// Баланс карты: 50000 руб.
//
// Золотая кредитная карта
// Номер карты: 2222-3333-4444-5555
// Холдер: Петр Петров
// Срок действия: 29.06.2030
// Баланс: 100000 руб.
// Оплата на сумму 10000 руб. выполнена.
// Начислено бонусных миль: 100.
// Всего бонусных миль: 600.
// Баланс карты: 90000 руб.
//
// Премиальная кредитная карта
// Номер карты: 3333-4444-5555-6666
// Холдер: Анна Смирнова
// Срок действия: 30.07.2029
// Баланс: 75000 руб.
// Баланс карты: 75000 руб.
//
// Корпоративная кредитная карта
// Номер карты: 4444-5555-6666-7777
// Холдер: Сергей Сидоров
// Срок действия: 18.09.2028
// Баланс: 200000 руб.
// Компания: ООО Ромашка
// Оплата на сумму 15000 руб. выполнена.
// Баланс карты: 185000 руб.
//
// Оплата на сумму 1000 руб. выполнена.
// Начислено бонусных миль: 10.
// Всего бонусных миль: 610.
// Баланс карты: 75000 руб.
// Номер карты: 4444-5555-6666-7777
// Холдер: Сергей Сидоров
// Срок действия: 18.09.2028
// Баланс: 185000 руб.
// Компания: ООО Ромашка
